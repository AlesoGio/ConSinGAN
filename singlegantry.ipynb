# %%
# !git clone https://github.com/AlesoGio/ConSinGAN.git
# Out:
# Cloning into 'ConSinGAN'...
# remote: Enumerating objects: 1609, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 1609 (delta 73), reused 80 (delta 66), pack-reused 1513 (from 1)
# Receiving objects: 100% (1609/1609), 81.33 MiB | 51.60 MiB/s, done.
# Resolving deltas: 100% (196/196), done.

# %%
# %cd ConSinGAN
# Out:
# /kaggle/working/ConSinGAN

# %%
# %cd /kaggle/working/ConSinGAN
# !git pull origin master
# Out:
# /kaggle/working/ConSinGAN
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 2.48 KiB | 1.24 MiB/s, done.
# From https://github.com/AlesoGio/ConSinGAN
#  * branch            master     -> FETCH_HEAD
#    4f54dc2..15bd7bf  master     -> origin/master
# Updating 4f54dc2..15bd7bf
# Fast-forward
#  Images/Harmonization/Image3_naive_mask.jpg | Bin 8031 -> 9018 bytes
#  1 file changed, 0 insertions(+), 0 deletions(-)

# %%
# Installa dipendenze
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 31.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 38.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 89.7 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.4/631.4 kB 32.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.6/36.6 MB 49.4 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 92.9 MB/s eta 0:00:00:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 92.7 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python main_train.py \
  --gpu 0 \
  --train_mode harmonization \
  --train_stages 3 \
  --min_size 120  \
  --max_size 2000 \
  --lrelu_alpha 0.3 \
  --niter 1000 \
  --batch_norm \
  --input_name Images/Harmonization/pencil_tree.jpg
  --naive_img Images/Harmonization/pencil_tree_naive.jpg
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.5'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 2025-05-17 10:04:39.221843: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747476279.244627     170 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747476279.251402     170 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python evaluate_model.py \
  --gpu 0 \
  --model_dir /kaggle/working/ConSinGAN/TrainedModels/Image3/2025_05_17_15_41_23_harmonization_fine-tune_train_depth_3_lr_scale_0.1_BN_act_lrelu_0.3 \
  --naive_img Images/Harmonization/Image3_seconda.jpg
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.5'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading models...
# Done. Results saved at: /kaggle/working/ConSinGAN/TrainedModels/Image3/2025_05_17_15_41_23_harmonization_fine-tune_train_depth_3_lr_scale_0.1_BN_act_lrelu_0.3/Evaluation

# %%
#####FINE-TUNE####
# !python main_train.py --gpu 0 --train_mode harmonization --input_name Images/Harmonization/Image3.jpg --naive_img Images/Harmonization/Image3_naive.jpg --fine_tune --model_dir /kaggle/working/ConSinGAN/TrainedModels/Image3/2025_05_16_16_56_38_harmonization_train_depth_3_lr_scale_0.1_BN_act_lrelu_0.3
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.5'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 2025-05-17 15:41:25.866234: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747496486.048684     106 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747496486.105104     106 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
####SERVE A CREARE UNO ZIP PER IL TRAINED MODEL

import shutil

# Percorso della cartella da comprimere
folder_path = '/kaggle/working/ConSinGAN/TrainedModels/Image3/2025_05_17_15_41_23_harmonization_fine-tune_train_depth_3_lr_scale_0.1_BN_act_lrelu_0.3'

# Percorso di output dello ZIP (nella stessa directory di lavoro)
zip_path = '/kaggle/working/harmonization_model.zip'

# Comprime la cartella in uno zip
shutil.make_archive(zip_path.replace('.zip', ''), 'zip', folder_path)
# Out:
# '/kaggle/working/harmonization_model.zip'
